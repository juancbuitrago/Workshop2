# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import sys

# %%
df = pd.read_csv("../outputs/merged_data.csv")
df.head()
# Out:
#            artists                                  album_name   track_name  \
# 0     joy williams                                 Front Porch  front porch
# 1   brandi carlile                   By The Way, I Forgive You     the joke
# 2  julieta venegas  Éxitos del Pop en Español de los Años 2000  limón y sal
# 3  julieta venegas  Éxitos del Pop en Español de los Años 2000  limón y sal
# 4  julieta venegas  Éxitos del Pop en Español de los Años 2000  limón y sal
#
#    popularity  duration_ms  explicit  danceability  energy  loudness  \
# 0          64       231813     False         0.567   0.224   -10.024
# 1          60       279373     False         0.236   0.578    -5.477
# 2           0       205213     False         0.625   0.653    -5.967
# 3           0       205213     False         0.625   0.653    -5.967
# 4           0       205213     False         0.625   0.653    -5.967
#
#    speechiness  acousticness    tempo  track_genre  year  \
# 0       0.0299         0.887  124.440     acoustic  2019
# 1       0.0404         0.327   75.367     acoustic  2018
# 2       0.0257         0.124  110.972     alt-rock  2006
# 3       0.0257         0.124  110.972  alternative  2006
# 4       0.0257         0.124  110.972        latin  2006
#
#                                title                         category  \
# 0  62nd Annual GRAMMY Awards  (2019)                  Best Folk Album
# 1  61st Annual GRAMMY Awards  (2018)  Best American Roots Performance
# 2  49th Annual GRAMMY Awards  (2006)             Best Latin Pop Album
# 3  49th Annual GRAMMY Awards  (2006)             Best Latin Pop Album
# 4  49th Annual GRAMMY Awards  (2006)             Best Latin Pop Album
#
#        nominee           artist  winner
# 0  front porch     joy williams    True
# 1     the joke   brandi carlile    True
# 2  limón y sal  julieta venegas    True
# 3  limón y sal  julieta venegas    True
# 4  limón y sal  julieta venegas    True

# %%
rows, columns = df.shape

print(f"rows:{rows}, columns: {columns}")
total_duplicates = df.duplicated().sum()
total_duplicates
# Out:
# rows:470, columns: 19
# 3

# %%
null_counts = df.isnull().sum()

plt.figure(figsize=(10, 6))
null_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Nulls Per Column')
plt.xlabel('Columns')
plt.ylabel('Null Count')
plt.xticks(rotation=45)
plt.tight_layout()  

plt.show()
